# %% [markdown]
# <a href="https://www.kaggle.com/code/gaganajayprajapati/credit-card-default-prediction-ipynb?scriptVersionId=182532982" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Credit%20Default.csv')

# %%
df.head()
# Out:
#         Income        Age         Loan  Loan to Income  Default
# 0  66155.92510  59.017015  8106.532131        0.122537        0
# 1  34415.15397  48.117153  6564.745018        0.190752        0
# 2  57317.17006  63.108049  8020.953296        0.139940        0
# 3  42709.53420  45.751972  6103.642260        0.142911        0
# 4  66952.68885  18.584336  8770.099235        0.130990        1

# %%
df.columns
# Out:
# Index(['Income', 'Age', 'Loan', 'Loan to Income', 'Default'], dtype='object')

# %%
y = df['Default']

# %%
X = df.drop(['Default'], axis=1)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 2529)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       523
#            1       0.79      0.83      0.81        77
#
#     accuracy                           0.95       600
#    macro avg       0.88      0.90      0.89       600
# weighted avg       0.95      0.95      0.95       600

# %%
print(accuracy_score(y_pred, y_test))
# Out:
# 0.95
